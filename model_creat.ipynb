# %%
import keras
from keras import Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Input, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.utils import plot_model
import pandas as pd
from keras.initializers import Constant

# %%
import pickle
import gzip
import numpy as np
f = gzip.open('mnist.pkl.gz', 'rb')
training_data, validation_data, test_data = pickle.load(f, encoding='latin1')
train_images, train_labels = training_data[0], training_data[1]
test_images, test_labels = test_data[0], test_data[1]

# %%
img_cols, img_rows = 28, 28

def make_model(cnn_units1=32, cnn_units2=64, dense_units=128, dropout1=0, dropout2=0):
    model = Sequential()
    model.add(Conv2D(cnn_units1, kernel_size=(5, 5),
                    padding='same',
                    kernel_initializer='random_uniform',
                    activation='relu',
                    input_shape=(img_rows, img_cols, 1)))
    model.add(Conv2D(cnn_units1, kernel_size=(5, 5),
                    padding='same',
                    kernel_initializer='random_uniform',
                    activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2),padding='same'))
    model.add(Dropout(dropout_rate_1))
    if cnn_units_2 > 0:
        model.add(Conv2D(cnn_units_2, kernel_size=(3, 3),
                 padding='same',
                 bias_initializer=Constant(0.02),
                 kernel_initializer='random_uniform',
                 activation='relu'))
        model.add(Conv2D(cnn_units_2, kernel_size=(3, 3),
                 padding='same',
                 bias_initializer=Constant(0.02),
                 kernel_initializer='random_uniform',
                 activation='relu'))
        model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='same'))
        model.add(Dropout(dropout_rate_2))
    model.add(Flatten())
    model.add(dense_units, activation='relu',
                bias_initializer=Constant(0.02),
                kernel_initializer='random_uniform'))
    model.add(BatchN)
